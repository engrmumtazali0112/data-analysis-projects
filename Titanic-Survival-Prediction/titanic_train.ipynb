# %% [markdown]
# # Titanic Data - Train Dataset

# %% [markdown]
# ## Data Cleaning and Exploratory Data Analysis for Train Dataset

# %%
# Load the training dataset
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

train_data_path = 'D:/Internship/Data Science Internship/Task2/train.csv'
train_df = pd.read_csv(train_data_path)

# Check for missing values
train_df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# ### Data Cleaning

# %%
# Fill missing values
train_df['Age'].fillna(train_df['Age'].median(), inplace=True)
train_df['Embarked'].fillna(train_df['Embarked'].mode()[0], inplace=True)
train_df.drop(columns=['Cabin'], inplace=True)

# Convert categorical variables to numeric
train_df['Sex'] = train_df['Sex'].map({'male': 0, 'female': 1})
train_df['Embarked'] = train_df['Embarked'].map({'C': 1, 'Q': 2, 'S': 3})

# Verify cleaning
train_df.isnull().sum()
# Out:
# C:\Users\3 STAR\AppData\Local\Temp\ipykernel_7616\3652849080.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   train_df['Age'].fillna(train_df['Age'].median(), inplace=True)
# C:\Users\3 STAR\AppData\Local\Temp\ipykernel_7616\3652849080.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %% [markdown]
# ### Exploratory Data Analysis

# %%
# Survival Distribution
sns.countplot(x='Survived', data=train_df)
plt.title('Survival Distribution')
plt.show()

# Correlation Heatmap
# Filter numeric columns only for correlation calculation
numeric_cols = train_df.select_dtypes(include=['number'])
sns.heatmap(numeric_cols.corr(), annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %%
# Survival by Gender
sns.barplot(x='Sex', y='Survived', data=train_df)
plt.title('Survival Rate by Gender')
plt.show()

# Survival by Passenger Class
sns.barplot(x='Pclass', y='Survived', data=train_df)
plt.title('Survival Rate by Passenger Class')
plt.show()
