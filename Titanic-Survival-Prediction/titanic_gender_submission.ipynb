# %% [markdown]
# # Titanic Data - Gender Submission Dataset

# %% [markdown]
# ## Analyze Gender-Based Predictions in Submission File

# %%
# Load the training dataset
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load the gender submission dataset
gender_submission_path = 'D:\\Internship\\Data Science Internship\\Task2\\gender_submission.csv'
gender_submission_df = pd.read_csv(gender_submission_path)

# Display the dataset
gender_submission_df.head()

# Analyze distribution of predictions
gender_submission_df['Survived'].value_counts().plot(kind='bar', title='Survival Predictions', xlabel='Survived', ylabel='Count')
plt.show()
